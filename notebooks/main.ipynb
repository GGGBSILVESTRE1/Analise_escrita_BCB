# %%
import os
import sys
import pandas as pd 

sys.path.append(os.path.abspath(os.path.join('..')))

from src.extraction import buscar_atas


atas = buscar_atas()
# Out:
# DEBUG: Acessando URL: https://www.bcb.gov.br/api/servico/sitebcb/atascopom/ultimas?quantidade=100&filtro=Id%20ne%20%27258%27
# DEBUG: Status Code: 200
# DEBUG: Chaves do JSON: dict_keys(['conteudo'])
# DEBUG: Quantidade de itens encontrados: 100

# %%
from src.extraction import extrair_texto_ata

atas['conteudo_ata'] = atas['LinkPagina'].apply(extrair_texto_ata)

# %%
print(atas['conteudo_ata'].info())
# Out:
# <class 'pandas.Series'>
# RangeIndex: 100 entries, 0 to 99
# Series name: conteudo_ata
# Non-Null Count  Dtype
# --------------  -----
# 100 non-null    str
# dtypes: str(1)
# memory usage: 932.0 bytes
# None

# %%
atas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DataReferencia          100 non-null    str
#  1   ImagemCapa              100 non-null    str
#  2   Titulo                  100 non-null    str
#  3   Url                     76 non-null     str
#  4   LinkPagina              100 non-null    str
#  5   EsconderDataReferencia  44 non-null     object
#  6   conteudo_ata            100 non-null    str
# dtypes: object(1), str(6)
# memory usage: 5.6+ KB

# %%
amostra = atas['conteudo_ata'].iloc[70]

print(f"Tipo do dado: {type(amostra)}")
print(f"Quantidade de caracteres: {len(amostra) if amostra else 0}")
print("-" * 30)
print("Início do texto extraído:")
print(amostra[:500] if amostra else "NADA FOI EXTRAÍDO")
# Out:
# Tipo do dado: <class 'str'>
# Quantidade de caracteres: 113
# ------------------------------
# Início do texto extraído:
# Banco Central do BrasilEssa pagina depende do javascript para abrir, favor habilitar o javascript do seu browser!
